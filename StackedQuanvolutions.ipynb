# %%
import torch
from torch import nn

import torchvision

import pennylane as qml
from pennylane import numpy as np
from pennylane.templates import RandomLayers

from sklearn.metrics import accuracy_score

# %%
class QonvLayer(nn.Module):
    def __init__(self, stride=2, device="default.qubit", wires=4, circuit_layers=4, n_rotations=8, out_channels=4, seed=None):
        super(QonvLayer, self).__init__()
        
        # init device
        self.wires = wires
        self.dev = qml.device(device, wires=self.wires)
        
        self.stride = stride
        self.out_channels = min(out_channels, wires)
        
        if seed is None:
            seed = np.random.randint(low=0, high=10e6)
            
        print("Initializing Circuit with random seed", seed)
        
        # random circuits
        @qml.qnode(device=self.dev)
        def circuit(inputs, weights):
            n_inputs=4
            # Encoding of 4 classical input values
            for j in range(n_inputs):
                qml.RY(inputs[j], wires=j)
            # Random quantum circuit
            RandomLayers(weights, wires=list(range(self.wires)), seed=seed)
            
            # Measurement producing 4 classical output values
            return [qml.expval(qml.PauliZ(j)) for j in range(self.out_channels)]
        
        weight_shapes = {"weights": [circuit_layers, n_rotations]}
        self.circuit = qml.qnn.TorchLayer(circuit, weight_shapes=weight_shapes)
    
    
    def draw(self):
        # build circuit by sending dummy data through it
        _ = self.circuit(inputs=torch.from_numpy(np.zeros(4)))
        print(self.circuit.qnode.draw())
        self.circuit.zero_grad()
        
    
    def forward(self, img):
        bs, h, w, ch = img.size()
        if ch > 1:
            img = img.mean(axis=-1).reshape(bs, h, w, 1)
                        
        kernel_size = 2        
        h_out = (h-kernel_size) // self.stride + 1
        w_out = (w-kernel_size) // self.stride + 1
        
        
        out = torch.zeros((bs, h_out, w_out, self.out_channels))
        
        # Loop over the coordinates of the top-left pixel of 2X2 squares
        for b in range(bs):
            for j in range(0, h_out, self.stride):
                for k in range(0, w_out, self.stride):
                    # Process a squared 2x2 region of the image with a quantum circuit
                    q_results = self.circuit(
                        inputs=torch.Tensor([
                            img[b, j, k, 0],
                            img[b, j, k + 1, 0],
                            img[b, j + 1, k, 0],
                            img[b, j + 1, k + 1, 0]
                        ])
                    )
                    # Assign expectation values to different channels of the output pixel (j/2, k/2)
                    for c in range(self.out_channels):
                        out[b, j // kernel_size, k // kernel_size, c] = q_results[c]
                        
                 
        return out

# %%
qonv = QonvLayer(circuit_layers=2, n_rotations=4, out_channels=4, stride=2)
qonv.draw()
x = torch.rand(size=(10,28,28,1))
qonv(x).shape
# Out:
# Initializing Circuit with random seed 7972349
#  0: ──RY(0.0)──╭C────────────────────────╭C──╭C────────────────────────╭C──┤ ⟨Z⟩
#  1: ──RY(0.0)──╰X──RX(5.041)──RX(2.571)──│───╰X──RX(5.931)──RX(0.853)──│───┤ ⟨Z⟩
#  2: ──RY(0.0)──╭C──RX(3.721)─────────────│───╭C──RX(0.243)─────────────│───┤ ⟨Z⟩
#  3: ──RY(0.0)──╰X──RY(1.885)─────────────╰X──╰X──RY(2.778)─────────────╰X──┤ ⟨Z⟩
# torch.Size([10, 14, 14, 4])

# %%
def transform(x):
    x = np.array(x)
    x = x/255.0
    
    return torch.from_numpy(x).float()

# %%
train_set = torchvision.datasets.MNIST(root='./mnist', train=True, download=True, transform=transform)
test_set = torchvision.datasets.MNIST(root='./mnist', train=False, download=True, transform=transform)

train_loader = torch.utils.data.DataLoader(dataset=train_set, batch_size=4)

# %% [markdown]
# # Experiment I (one Quanvolutional Layer)

# %%
def training_experiment_1():
    print("Starting Experiment I")

    model = torch.nn.Sequential(
        QonvLayer(stride=2, circuit_layers=2, n_rotations=4, out_channels=4),
        torch.nn.Flatten(),
        torch.nn.Linear(in_features=14*14*4, out_features=10)
    )

    model.train()

    optimizer = torch.optim.Adam(params=model.parameters(), lr=0.01)
    criterion = torch.nn.CrossEntropyLoss()

    for epoch in range(1):
        for i, (x, y) in enumerate(train_loader):

            # prepare inputs and labels
            x = x.view(-1, 28, 28, 1)
            y = y.long()

            # reset optimizer
            optimizer.zero_grad()

            # engage
            y_pred = model(x)

            # error, gradients and optimization
            loss = criterion(y_pred, y)  
            loss.backward()
            optimizer.step()

            # output
            acc = accuracy_score(y, y_pred.argmax(-1).numpy())       

            print("Epoch:", epoch, "\tStep:", i, "\tAccuracy:", acc, "\tLoss:", loss.item())
            print("Gradients Layer 0:")
            print(model[0].circuit.weights.grad)

            if i % 5 == 0:
                model[0].draw()
            
            print("---------------------------------------")
            
            # early break
            if i > 0 and i % 10 == 0:
                break
            
    return model

# %% [markdown]
# # Experiment II (two stacked Quanvolutional Layers)

# %%
def training_experiment_2():
    print("Starting Experiment II")

    model = torch.nn.Sequential(
        QonvLayer(stride=2, circuit_layers=2, n_rotations=4, out_channels=4),
        QonvLayer(stride=2, circuit_layers=2, n_rotations=4, out_channels=4),
        torch.nn.Flatten(),
        torch.nn.Linear(in_features=7*7*4, out_features=10)
    )

    model.train()

    optimizer = torch.optim.Adam(params=model.parameters(), lr=0.01)
    criterion = torch.nn.CrossEntropyLoss()

    for epoch in range(1):
        for i, (x, y) in enumerate(train_loader):

            # prepare inputs and labels
            x = x.view(-1, 28, 28, 1)
            y = y.long()

            # reset optimizer
            optimizer.zero_grad()

            # engage
            y_pred = model(x)

            # error, gradients and optimization
            loss = criterion(y_pred, y)  
            loss.backward()
            optimizer.step()


            # output
            acc = accuracy_score(y, y_pred.argmax(-1).numpy())  

            print("Epoch:", epoch, "\tStep:", i, "\tAccuracy:", acc, "\tLoss:", loss.item())
            print("Gradients Layer 0:")
            print(model[0].circuit.weights.grad)
            print("Gradients Layer 1:")
            print(model[1].circuit.weights.grad)

            if i % 5 == 0:
                print("Current Circuit Layer 0:")
                model[0].draw()
                print("Current Circuit Layer 1:")
                model[1].draw()

            print("---------------------------------------")
            
            # early break
            if i > 0 and i % 10 == 0:
                break
            
    return model

# %%
if __name__ == "__main__":
    training_experiment_1()
    training_experiment_2()
# Out:
# Starting Experiment I
# Initializing Circuit with random seed 7143677
# Epoch: 0 	Step: 0 	Accuracy: 0.0 	Loss: 2.257474184036255
# Gradients Layer 0:
# tensor([[ 0.0232,  0.0314, -0.0131, -0.0099],
#         [-0.0143,  0.0237, -0.0131,  0.0546]])
#  0: ──RY(0.0)──╭X───────────────────────────────────────────╭X───────────────────────────────────┤ ⟨Z⟩
#  1: ──RY(0.0)──╰C──────────RX(2.473)──RZ(1.893)──RX(2.425)──╰C──RX(5.727)──RZ(2.096)──RX(5.288)──┤ ⟨Z⟩
#  2: ──RY(0.0)────────────────────────────────────────────────────────────────────────────────────┤ ⟨Z⟩
#  3: ──RY(0.0)───RX(3.926)──RX(4.196)─────────────────────────────────────────────────────────────┤ ⟨Z⟩
#
# ---------------------------------------
# Epoch: 0 	Step: 1 	Accuracy: 0.0 	Loss: 3.2840704917907715
# Gradients Layer 0:
# tensor([[ 0.2775,  0.3587,  0.6925,  0.3129],
#         [-0.0316,  0.1131,  0.6925,  0.1894]])
# ---------------------------------------
# Epoch: 0 	Step: 2 	Accuracy: 0.25 	Loss: 2.0612998008728027
# Gradients Layer 0:
# tensor([[ 0.1325,  0.1627,  0.1562,  0.1468],
#         [-0.0098,  0.0586,  0.1562,  0.0853]])
# ---------------------------------------
# Epoch: 0 	Step: 3 	Accuracy: 0.25 	Loss: 3.6830782890319824
# Gradients Layer 0:
# tensor([[ 0.4453,  0.6027,  0.7356,  0.4455],
#         [-0.0822,  0.1624,  0.7356,  0.3506]])
# ---------------------------------------
# Epoch: 0 	Step: 4 	Accuracy: 0.0 	Loss: 4.296343803405762
# Gradients Layer 0:
# tensor([[ 0.5938,  0.7975,  0.8804,  0.6404],
#         [-0.0952,  0.2307,  0.8804,  0.4575]])
# ---------------------------------------
# Epoch: 0 	Step: 5 	Accuracy: 0.0 	Loss: 2.3257884979248047
# Gradients Layer 0:
# tensor([[ 0.1253,  0.1808,  0.2118,  0.0930],
#         [-0.0380,  0.0461,  0.2118,  0.1325]])
#  0: ──RY(0.0)──╭X───────────────────────────────────────────╭X───────────────────────────────────┤ ⟨Z⟩
#  1: ──RY(0.0)──╰C──────────RX(2.431)──RZ(1.851)──RX(2.384)──╰C──RX(5.772)──RZ(2.052)──RX(5.243)──┤ ⟨Z⟩
#  2: ──RY(0.0)────────────────────────────────────────────────────────────────────────────────────┤ ⟨Z⟩
#  3: ──RY(0.0)───RX(3.886)──RX(4.157)─────────────────────────────────────────────────────────────┤ ⟨Z⟩
#
# ---------------------------------------
# Epoch: 0 	Step: 6 	Accuracy: 0.25 	Loss: 1.936706781387329
# Gradients Layer 0:
# tensor([[-0.0077, -0.0178, -0.0035,  0.0114],
#         [ 0.0043,  0.0223, -0.0035,  0.0157]])
# ---------------------------------------
# Epoch: 0 	Step: 7 	Accuracy: 0.25 	Loss: 3.0497961044311523
# Gradients Layer 0:
# tensor([[ 0.2594,  0.3637,  0.3344,  0.2922],
#         [-0.0501,  0.1046,  0.3344,  0.2276]])
# ---------------------------------------
# Epoch: 0 	Step: 8 	Accuracy: 0.0 	Loss: 2.9497766494750977
# Gradients Layer 0:
# tensor([[ 0.2896,  0.4171,  0.3986,  0.2855],
#         [-0.0661,  0.0975,  0.3986,  0.2572]])
# ---------------------------------------
# Epoch: 0 	Step: 9 	Accuracy: 0.0 	Loss: 2.7865259647369385
# Gradients Layer 0:
# tensor([[ 0.2313,  0.3341,  0.3302,  0.1996],
#         [-0.0582,  0.0782,  0.3302,  0.2202]])
# ---------------------------------------
# Epoch: 0 	Step: 10 	Accuracy: 0.0 	Loss: 2.6995677947998047
# Gradients Layer 0:
# tensor([[ 0.1306,  0.1772,  0.3523,  0.1271],
#         [-0.0295,  0.0700,  0.3523,  0.1470]])
#  0: ──RY(0.0)──╭X───────────────────────────────────────────╭X───────────────────────────────────┤ ⟨Z⟩
#  1: ──RY(0.0)──╰C──────────RX(2.392)──RZ(1.811)──RX(2.346)──╰C──RX(5.812)──RZ(2.011)──RX(5.202)──┤ ⟨Z⟩
#  2: ──RY(0.0)────────────────────────────────────────────────────────────────────────────────────┤ ⟨Z⟩
#  3: ──RY(0.0)───RX(3.849)──RX(4.119)─────────────────────────────────────────────────────────────┤ ⟨Z⟩
#
# ---------------------------------------
# Starting Experiment II
# Initializing Circuit with random seed 3005004
# Initializing Circuit with random seed 2308805
# Epoch: 0 	Step: 0 	Accuracy: 0.0 	Loss: 2.4628794193267822
# Gradients Layer 0:
# None
# Gradients Layer 1:
# tensor([[-0.0646, -0.0038, -0.0646, -0.0082],
#         [-0.0646,  0.0081, -0.0646, -0.0203]])
# Current Circuit Layer 0:
#  0: ──RY(0.0)──RZ(3.787)──RX(6.086)──RZ(1.129)──RX(4.317)──┤ ⟨Z⟩
#  1: ──RY(0.0)──RZ(4.248)──RZ(4.424)────────────────────────┤ ⟨Z⟩
#  2: ──RY(0.0)──RY(2.704)──RY(0.745)────────────────────────┤ ⟨Z⟩
#  3: ──RY(0.0)──────────────────────────────────────────────┤ ⟨Z⟩
#
# Current Circuit Layer 1:
#  0: ──RY(0.0)─────────────╭C──RY(0.055)─────────────╭X──RX(3.309)──╭C──RY(6.051)──╭X──RX(3.854)──┤ ⟨Z⟩
#  1: ──RY(0.0)──RY(5.547)──│───RY(5.24)───RY(0.615)──│───RY(5.369)──│──────────────│──────────────┤ ⟨Z⟩
#  2: ──RY(0.0)─────────────╰X────────────────────────╰C─────────────╰X─────────────╰C─────────────┤ ⟨Z⟩
#  3: ──RY(0.0)────────────────────────────────────────────────────────────────────────────────────┤ ⟨Z⟩
#
# ---------------------------------------
# Epoch: 0 	Step: 1 	Accuracy: 0.25 	Loss: 2.4475271701812744
# Gradients Layer 0:
# None
# Gradients Layer 1:
# tensor([[ 0.0288, -0.0091,  0.0288, -0.0262],
#         [ 0.0288,  0.0164,  0.0288, -0.0341]])
# ---------------------------------------
# Epoch: 0 	Step: 2 	Accuracy: 0.25 	Loss: 2.0933961868286133
# Gradients Layer 0:
# None
# Gradients Layer 1:
# tensor([[ 0.0845, -0.0053,  0.0845, -0.0156],
#         [ 0.0845,  0.0040,  0.0845, -0.0065]])
# ---------------------------------------
# Epoch: 0 	Step: 3 	Accuracy: 0.25 	Loss: 2.8486008644104004
# Gradients Layer 0:
# None
# Gradients Layer 1:
# tensor([[-0.2562, -0.0096, -0.2562, -0.0478],
#         [-0.2562,  0.1071, -0.2562, -0.2545]])
# ---------------------------------------
# Epoch: 0 	Step: 4 	Accuracy: 0.0 	Loss: 3.2593417167663574
# Gradients Layer 0:
# None
# Gradients Layer 1:
# tensor([[-0.4572, -0.0265, -0.4572, -0.0772],
#         [-0.4572,  0.1102, -0.4572, -0.2533]])
# ---------------------------------------
# Epoch: 0 	Step: 5 	Accuracy: 0.25 	Loss: 2.148404121398926
# Gradients Layer 0:
# None
# Gradients Layer 1:
# tensor([[ 1.6980e-03,  7.9244e-05,  1.6980e-03,  1.8534e-03],
#         [ 1.6980e-03, -7.0991e-03,  1.6980e-03,  9.5685e-03]])
# Current Circuit Layer 0:
#  0: ──RY(0.0)──RZ(3.787)──RX(6.086)──RZ(1.129)──RX(4.317)──┤ ⟨Z⟩
#  1: ──RY(0.0)──RZ(4.248)──RZ(4.424)────────────────────────┤ ⟨Z⟩
#  2: ──RY(0.0)──RY(2.704)──RY(0.745)────────────────────────┤ ⟨Z⟩
#  3: ──RY(0.0)──────────────────────────────────────────────┤ ⟨Z⟩
#
# Current Circuit Layer 1:
#  0: ──RY(0.0)─────────────╭C──RY(0.099)─────────────╭X──RX(3.353)──╭C──RY(6.011)──╭X──RX(3.894)──┤ ⟨Z⟩
#  1: ──RY(0.0)──RY(5.563)──│───RY(5.256)──RY(0.631)──│───RY(5.385)──│──────────────│──────────────┤ ⟨Z⟩
#  2: ──RY(0.0)─────────────╰X────────────────────────╰C─────────────╰X─────────────╰C─────────────┤ ⟨Z⟩
#  3: ──RY(0.0)────────────────────────────────────────────────────────────────────────────────────┤ ⟨Z⟩
#
# ---------------------------------------
# Epoch: 0 	Step: 6 	Accuracy: 0.25 	Loss: 1.932826280593872
# Gradients Layer 0:
# None
# Gradients Layer 1:
# tensor([[ 0.1682, -0.0032,  0.1682, -0.0006],
#         [ 0.1682, -0.0264,  0.1682,  0.0685]])
# ---------------------------------------
# Epoch: 0 	Step: 7 	Accuracy: 0.0 	Loss: 2.8827261924743652
# Gradients Layer 0:
# None
# Gradients Layer 1:
# tensor([[-0.2836, -0.0222, -0.2836, -0.0536],
#         [-0.2836,  0.0766, -0.2836, -0.1809]])
# ---------------------------------------
# Epoch: 0 	Step: 8 	Accuracy: 0.0 	Loss: 2.6148486137390137
# Gradients Layer 0:
# None
# Gradients Layer 1:
# tensor([[-0.3662, -0.0029, -0.3662, -0.0191],
#         [-0.3662,  0.0644, -0.3662, -0.1532]])
# ---------------------------------------
# Epoch: 0 	Step: 9 	Accuracy: 0.0 	Loss: 2.9319686889648438
# Gradients Layer 0:
# None
# Gradients Layer 1:
# tensor([[-4.7075e-01, -3.1058e-05, -4.7075e-01, -2.9789e-02],
#         [-4.7075e-01,  1.1925e-01, -4.7075e-01, -2.8169e-01]])
# ---------------------------------------
# Epoch: 0 	Step: 10 	Accuracy: 0.0 	Loss: 2.6774697303771973
# Gradients Layer 0:
# None
# Gradients Layer 1:
# tensor([[-0.2190, -0.0008, -0.2190, -0.0091],
#         [-0.2190,  0.0467, -0.2190, -0.1111]])
# Current Circuit Layer 0:
#  0: ──RY(0.0)──RZ(3.787)──RX(6.086)──RZ(1.129)──RX(4.317)──┤ ⟨Z⟩
#  1: ──RY(0.0)──RZ(4.248)──RZ(4.424)────────────────────────┤ ⟨Z⟩
#  2: ──RY(0.0)──RY(2.704)──RY(0.745)────────────────────────┤ ⟨Z⟩
#  3: ──RY(0.0)──────────────────────────────────────────────┤ ⟨Z⟩
#
# Current Circuit Layer 1:
#  0: ──RY(0.0)─────────────╭C──RY(0.134)────────────╭X──RX(3.389)──╭C──RY(5.978)──╭X──RX(3.927)──┤ ⟨Z⟩
#  1: ──RY(0.0)──RY(5.591)──│───RY(5.285)──RY(0.66)──│───RY(5.414)──│──────────────│──────────────┤ ⟨Z⟩
#  2: ──RY(0.0)─────────────╰X───────────────────────╰C─────────────╰X─────────────╰C─────────────┤ ⟨Z⟩
#  3: ──RY(0.0)───────────────────────────────────────────────────────────────────────────────────┤ ⟨Z⟩
#
# ---------------------------------------
